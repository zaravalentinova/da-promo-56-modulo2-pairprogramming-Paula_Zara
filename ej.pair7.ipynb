# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd

# %%
try:
  cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='northwind')
  print("ok")
# en caso de que no lo consigas por que hay algún error entonces ...
except mysql.connector.Error as err:

  # si es un error con la contraseña devuelveme un mensaje de acceso denegado ya que tenemos problemas con la contraseña
  if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
    print("Something is wrong with your user name or password")
  
  # si el error no tiene que ver con la contraseña, puede ser porque la base de datos no exista, devuelveme un mensaje de que la base de datos no existe
  elif err.errno == errorcode.ER_BAD_DB_ERROR:
    print("Database does not exist")
  
  # si no es por ninguno de los errores anteriores, printeame cual es el error que estoy teniendo en mi conexión
  else:
    print(err)
# Out:
# ok

# %%
cursor = cnx.cursor()

# %%
sql_bbdd = """CREATE SCHEMA IF NOT EXISTS northwind;"""

sql_use = "USE northwind;"

# %%
cursor.execute(sql_bbdd)
cursor.execute(sql_use)

# %%
query = """
SELECT column_name
FROM information_schema.columns
WHERE table_schema = 'northwind'
  AND table_name = 'customers';
  """

# %%
cursor.execute(query)

# %%
columnas=cursor.fetchall()

# %%
for c in columnas:
    print(c[0])
# Out:
# customer_id
# company_name
# contact_name
# contact_title
# address
# city
# region
# postal_code
# country
# phone
# fax

# %%
ciudad = """
SELECT *
    FROM customers
        WHERE city = 'London' OR city = 'Seattle';
"""

# %%
cursor = cnx.cursor()
cursor.execute(ciudad)

# %%
res = cursor.fetchall()
print(res)
# Out:
# [('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', '', 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'), ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', '', 'EC2 5NT', 'UK', '(171) 555-1212', ''), ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Sales Representative', 'Berkeley Gardens 12  Brewery', 'London', '', 'WX1 6LT', 'UK', '(171) 555-2282', '(171) 555-9199'), ('EASTC', 'Eastern Connection', 'Ann Devon', 'Sales Agent', '35 King George', 'London', '', 'WX3 6FW', 'UK', '(171) 555-0297', '(171) 555-3373'), ('NORTS', 'North/South', 'Simon Crowther', 'Sales Associate', 'South House 300 Queensbridge', 'London', '', 'SW7 1RZ', 'UK', '(171) 555-7733', '(171) 555-2530'), ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Sales Manager', '90 Wadhurst Rd.', 'London', '', 'OX15 4NB', 'UK', '(171) 555-1717', '(171) 555-5646'), ('WHITC', 'White Clover Markets', 'Karl Jablonski', 'Owner', '305 - 14th Ave. S. Suite 3B', 'Seattle', 'WA', '98128', 'USA', '(206) 555-4112', '(206) 555-4115')]

# %%
pd.DataFrame(res)
# Out:
#       0                      1                  2                     3   \
# 0  AROUT        Around the Horn       Thomas Hardy  Sales Representative
# 1  BSBEV          B's Beverages  Victoria Ashworth  Sales Representative
# 2  CONSH  Consolidated Holdings    Elizabeth Brown  Sales Representative
# 3  EASTC     Eastern Connection          Ann Devon           Sales Agent
# 4  NORTS            North/South     Simon Crowther       Sales Associate
# 5  SEVES     Seven Seas Imports         Hari Kumar         Sales Manager
# 6  WHITC   White Clover Markets     Karl Jablonski                 Owner
#
#                              4        5   6         7    8               9   \
# 0               120 Hanover Sq.   London       WA1 1DP   UK  (171) 555-7788
# 1             Fauntleroy Circus   London       EC2 5NT   UK  (171) 555-1212
# 2  Berkeley Gardens 12  Brewery   London       WX1 6LT   UK  (171) 555-2282
# 3                35 King George   London       WX3 6FW   UK  (171) 555-0297
# 4  South House 300 Queensbridge   London       SW7 1RZ   UK  (171) 555-7733
# 5               90 Wadhurst Rd.   London      OX15 4NB   UK  (171) 555-1717
# 6   305 - 14th Ave. S. Suite 3B  Seattle  WA     98128  USA  (206) 555-4112
#
#                10
# 0  (171) 555-6750
# 1
# 2  (171) 555-9199
# 3  (171) 555-3373
# 4  (171) 555-2530
# 5  (171) 555-5646
# 6  (206) 555-4115

# %%
cursor.description
# Out:
# [('customer_id', 254, None, None, None, None, 0, 20483, 255),
#  ('company_name', 253, None, None, None, None, 0, 20489, 255),
#  ('contact_name', 253, None, None, None, None, 1, 0, 255),
#  ('contact_title', 253, None, None, None, None, 1, 0, 255),
#  ('address', 253, None, None, None, None, 1, 0, 255),
#  ('city', 253, None, None, None, None, 1, 16392, 255),
#  ('region', 253, None, None, None, None, 1, 16392, 255),
#  ('postal_code', 253, None, None, None, None, 1, 16392, 255),
#  ('country', 253, None, None, None, None, 1, 0, 255),
#  ('phone', 253, None, None, None, None, 1, 0, 255),
#  ('fax', 253, None, None, None, None, 1, 0, 255)]

# %%
nom_col = []

for c in cursor.description:
    nom_col.append(c[0])
    print(c[0])
    print("--------------")
# Out:
# customer_id
# --------------
# company_name
# --------------
# contact_name
# --------------
# contact_title
# --------------
# address
# --------------
# city
# --------------
# region
# --------------
# postal_code
# --------------
# country
# --------------
# phone
# --------------
# fax
# --------------

# %%
nom_col
# Out:
# ['customer_id',
#  'company_name',
#  'contact_name',
#  'contact_title',
#  'address',
#  'city',
#  'region',
#  'postal_code',
#  'country',
#  'phone',
#  'fax']

# %%
df1 = pd.DataFrame(res, columns=nom_col)

# %%
df1
# Out:
#   customer_id           company_name       contact_name         contact_title  \
# 0       AROUT        Around the Horn       Thomas Hardy  Sales Representative
# 1       BSBEV          B's Beverages  Victoria Ashworth  Sales Representative
# 2       CONSH  Consolidated Holdings    Elizabeth Brown  Sales Representative
# 3       EASTC     Eastern Connection          Ann Devon           Sales Agent
# 4       NORTS            North/South     Simon Crowther       Sales Associate
# 5       SEVES     Seven Seas Imports         Hari Kumar         Sales Manager
# 6       WHITC   White Clover Markets     Karl Jablonski                 Owner
#
#                         address     city region postal_code country  \
# 0               120 Hanover Sq.   London            WA1 1DP      UK
# 1             Fauntleroy Circus   London            EC2 5NT      UK
# 2  Berkeley Gardens 12  Brewery   London            WX1 6LT      UK
# 3                35 King George   London            WX3 6FW      UK
# 4  South House 300 Queensbridge   London            SW7 1RZ      UK
# 5               90 Wadhurst Rd.   London           OX15 4NB      UK
# 6   305 - 14th Ave. S. Suite 3B  Seattle     WA       98128     USA
#
#             phone             fax
# 0  (171) 555-7788  (171) 555-6750
# 1  (171) 555-1212
# 2  (171) 555-2282  (171) 555-9199
# 3  (171) 555-0297  (171) 555-3373
# 4  (171) 555-7733  (171) 555-2530
# 5  (171) 555-1717  (171) 555-5646
# 6  (206) 555-4112  (206) 555-4115

# %%
df1.head(10)
# Out:
#   customer_id           company_name       contact_name         contact_title  \
# 0       AROUT        Around the Horn       Thomas Hardy  Sales Representative
# 1       BSBEV          B's Beverages  Victoria Ashworth  Sales Representative
# 2       CONSH  Consolidated Holdings    Elizabeth Brown  Sales Representative
# 3       EASTC     Eastern Connection          Ann Devon           Sales Agent
# 4       NORTS            North/South     Simon Crowther       Sales Associate
# 5       SEVES     Seven Seas Imports         Hari Kumar         Sales Manager
# 6       WHITC   White Clover Markets     Karl Jablonski                 Owner
#
#                         address     city region postal_code country  \
# 0               120 Hanover Sq.   London            WA1 1DP      UK
# 1             Fauntleroy Circus   London            EC2 5NT      UK
# 2  Berkeley Gardens 12  Brewery   London            WX1 6LT      UK
# 3                35 King George   London            WX3 6FW      UK
# 4  South House 300 Queensbridge   London            SW7 1RZ      UK
# 5               90 Wadhurst Rd.   London           OX15 4NB      UK
# 6   305 - 14th Ave. S. Suite 3B  Seattle     WA       98128     USA
#
#             phone             fax
# 0  (171) 555-7788  (171) 555-6750
# 1  (171) 555-1212
# 2  (171) 555-2282  (171) 555-9199
# 3  (171) 555-0297  (171) 555-3373
# 4  (171) 555-7733  (171) 555-2530
# 5  (171) 555-1717  (171) 555-5646
# 6  (206) 555-4112  (206) 555-4115

# %%
df1.tail(10)
# Out:
#   customer_id           company_name       contact_name         contact_title  \
# 0       AROUT        Around the Horn       Thomas Hardy  Sales Representative
# 1       BSBEV          B's Beverages  Victoria Ashworth  Sales Representative
# 2       CONSH  Consolidated Holdings    Elizabeth Brown  Sales Representative
# 3       EASTC     Eastern Connection          Ann Devon           Sales Agent
# 4       NORTS            North/South     Simon Crowther       Sales Associate
# 5       SEVES     Seven Seas Imports         Hari Kumar         Sales Manager
# 6       WHITC   White Clover Markets     Karl Jablonski                 Owner
#
#                         address     city region postal_code country  \
# 0               120 Hanover Sq.   London            WA1 1DP      UK
# 1             Fauntleroy Circus   London            EC2 5NT      UK
# 2  Berkeley Gardens 12  Brewery   London            WX1 6LT      UK
# 3                35 King George   London            WX3 6FW      UK
# 4  South House 300 Queensbridge   London            SW7 1RZ      UK
# 5               90 Wadhurst Rd.   London           OX15 4NB      UK
# 6   305 - 14th Ave. S. Suite 3B  Seattle     WA       98128     USA
#
#             phone             fax
# 0  (171) 555-7788  (171) 555-6750
# 1  (171) 555-1212
# 2  (171) 555-2282  (171) 555-9199
# 3  (171) 555-0297  (171) 555-3373
# 4  (171) 555-7733  (171) 555-2530
# 5  (171) 555-1717  (171) 555-5646
# 6  (206) 555-4112  (206) 555-4115

# %%
# 5 filas aleatorias
df1.sample(5)
# Out:
#   customer_id           company_name       contact_name         contact_title  \
# 1       BSBEV          B's Beverages  Victoria Ashworth  Sales Representative
# 3       EASTC     Eastern Connection          Ann Devon           Sales Agent
# 0       AROUT        Around the Horn       Thomas Hardy  Sales Representative
# 4       NORTS            North/South     Simon Crowther       Sales Associate
# 2       CONSH  Consolidated Holdings    Elizabeth Brown  Sales Representative
#
#                         address    city region postal_code country  \
# 1             Fauntleroy Circus  London            EC2 5NT      UK
# 3                35 King George  London            WX3 6FW      UK
# 0               120 Hanover Sq.  London            WA1 1DP      UK
# 4  South House 300 Queensbridge  London            SW7 1RZ      UK
# 2  Berkeley Gardens 12  Brewery  London            WX1 6LT      UK
#
#             phone             fax
# 1  (171) 555-1212
# 3  (171) 555-0297  (171) 555-3373
# 0  (171) 555-7788  (171) 555-6750
# 4  (171) 555-7733  (171) 555-2530
# 2  (171) 555-2282  (171) 555-9199

# %%
#nulas? resultado columnas
df1.isnull().sum() #en total/por columna
# Out:
# customer_id      0
# company_name     0
# contact_name     0
# contact_title    0
# address          0
# city             0
# region           0
# postal_code      0
# country          0
# phone            0
# fax              0
# dtype: int64

# %%
df1.describe() #los principales estadísticos
# Out:
#        customer_id     company_name  contact_name         contact_title  \
# count            7                7             7                     7
# unique           7                7             7                     5
# top          AROUT  Around the Horn  Thomas Hardy  Sales Representative
# freq             1                1             1                     3
#
#                 address    city region postal_code country           phone  \
# count                 7       7      7           7       7               7
# unique                7       2      2           7       2               7
# top     120 Hanover Sq.  London            WA1 1DP      UK  (171) 555-7788
# freq                  1       6      6           1       6               1
#
#                    fax
# count                7
# unique               7
# top     (171) 555-6750
# freq                 1

# %%
for c in columnas:
    print(c[0])
    #nombre de las columnas del Dataframe
# Out:
# customer_id
# company_name
# contact_name
# contact_title
# address
# city
# region
# postal_code
# country
# phone
# fax
