# %%
import json
import pandas as pd

# %% [markdown]
# Abrir el archivo, creando un dataframe. Aseguraros de que no incluye la columna "Unnamed: 0".

# %%
df = pd.read_csv("files/videogames.csv")

# %%
#df = pd.read_csv("files/videogames.csv", index_col=0)

# %%
df = df.drop(columns=["Unnamed: 0"])  #elimina columna

# %%
df
# Out:
#                                       name  \
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# 5                  The Last of Us: Part II
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4      https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
# ...

# %% [markdown]
# Guardar el dataframe en formato Excel y después crear un dataframe con el Excel. ¿El dataframe es similar al que teníais antes?

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.to_excel("files/videogames.xlsx", index= False)

# %%
df
# Out:
#                                       name  \
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# 5                  The Last of Us: Part II
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4      https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
# ...

# %%
df.to_csv("files/archivocsv/videogames.csv", index=False)

# %%
with open("files/files1/personal.json", "r") as f:
    personal = json.load(f)

# %%
type(personal)
# Out:
# dict

# %%
df = pd.json_normalize(personal)

# %%
df
# Out:
#                                              workers
# 0  [{'nombre': 'Ana', 'edad': 34, 'experiencia': ...

# %%
df = pd.DataFrame(personal["workers"])

# %%
personal.keys()
# Out:
# dict_keys(['workers'])

# %%
df
# Out:
#   nombre  edad  experiencia   nivel  salario mascota
# 0    Ana    34            5  Senior    50000   gatos
# 1    Eva    37            2     Mid    35000     NaN
# 2  Marta    27            1  Junior    25000     NaN
# 3  Paula    30            3     Mid    35000     NaN
